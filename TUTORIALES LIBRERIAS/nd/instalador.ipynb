# %%
pip install sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.1 MB 435.7 kB/s eta 0:00:05
#    - -------------------------------------- 0.1/2.1 MB 409.6 kB/s eta 0:00:05
#    -- ------------------------------------- 0.1/2.1 MB 595.3 kB/s eta 0:00:04
#    -- ------------------------------------- 0.1/2.1 MB 554.9 kB/s eta 0:00:04
#    -- ------------------------------------- 0.2/2.1 MB 573.4 kB/s eta 0:00:04
#    --- ------------------------------------ 0.2/2.1 MB 623.6 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/2.1 MB 655.6 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.3/2.1 MB 605.3 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.3/2.1 MB 632.7 kB/s eta 0:00:03
#    ------ --------------------------------- 0.3/2.1 MB 634.7 kB/s eta 0:00:03
# ...
